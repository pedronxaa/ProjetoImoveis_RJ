# %%
import cloudscraper
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
headers = {

'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'

}
dados_rj = ['https://www.zapimoveis.com.br/aluguel/apartamentos/rj+rio-de-janeiro/?onde=%2CRio+de+Janeiro%2CRio+de+Janeiro%2C%2C%2C%2C%2Ccity%2CBR>Rio+de+Janeiro>NULL>Rio+de+Janeiro%2C-22.906847%2C-43.172897%2C&tipos=apartamento_residencial&pagina=1&transacao=aluguel'] + \
             ['https://www.zapimoveis.com.br/aluguel/apartamentos/rj+rio-de-janeiro/?onde=%2CRio+de+Janeiro%2CRio+de+Janeiro%2C%2C%2C%2C%2Ccity%2CBR>Rio+de+Janeiro>NULL>Rio+de+Janeiro%2C-22.906847%2C-43.172897%2C&tipos=apartamento_residencial&pagina={}&transacao=aluguel'.format(i) for i in range(2, 323)]

# %%
data = []
for dados in dados_rj:
    response = scraper.get(dados, headers=headers)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')

    pagina_atual = soup.find_all('li', {'data-cy' : 'rp-property-cd'})
    
    for item in pagina_atual:
        local_element = item.find('h2', {'data-cy': 'rp-cardProperty-location-txt'})
        local = local_element.text.strip() if local_element else 'NA'

        area_element = item.find('li', {'data-cy': 'rp-cardProperty-propertyArea-txt'})
        area = area_element.text.strip() if area_element else 'NA'
        
        quartos_element = item.find('li', {'data-cy': 'rp-cardProperty-bedroomQuantity-txt'})
        quartos = quartos_element.text.strip() if quartos_element else 'NA'
        
        banheiros_element = item.find('li', {'data-cy': 'rp-cardProperty-bathroomQuantity-txt'})
        banheiros = banheiros_element.text.strip() if banheiros_element else 'NA'
        
        vagas_element = item.find('li', {'data-cy': 'rp-cardProperty-parkingSpacesQuantity-txt'})
        vagas = vagas_element.text.strip() if vagas_element else 'NA' 

        preco_element = item.find('div', {'data-cy' : 'rp-cardProperty-price-txt'})
        preco = preco_element.text.strip() if preco_element else 'NA'
        
        link_element = item.find('a', href=True)
        link = None
        if link_element and link_element['href'].startswith('https://www.zapimoveis.com.br/imovel/'):
            link = link_element['href']

        data.append({
            'Local': local, 
            'Preço': preco,
            'Área': area,
            'Quartos': quartos,
            'Banheiros': banheiros,
            'Vagas': vagas,
            'Link': link
        })
    
    time.sleep(1)

# %%
database = pd.DataFrame(data)
database.to_csv('imoveis_rio.csv', index = False, header= False)

# %%
db = pd.read_csv('imoveis_rio.csv', sep=',')
db.head()
# Out:
#   Apartamento para alugar em Vila Kosmos, Rio de Janeiro  \
# 0  Apartamento para alugar em Botafogo, Rio de Ja...
# 1  Apartamento para alugar em Barra da Tijuca, Ri...
# 2  Apartamento para alugar em Tijuca, Rio de Janeiro
# 3  Apartamento para alugar em Freguesia (Jacarepa...
# 4  Apartamento para alugar em Campo Grande, Rio d...
#
#                R$ 1.800/mêsCond. R$ 450 • IPTU R$ 49  Tamanho do imóvel 85 m²  \
# 0  R$ 4.300/mêsCond. R$ 918 • IPTU R$ 320Preço ab...  Tamanho do imóvel 84 m²
# 1  R$ 3.500/mêsCond. R$ 1.960 • IPTU R$ 228Preço ...  Tamanho do imóvel 68 m²
# 2             R$ 3.200/mêsCond. R$ 857 • IPTU R$ 226  Tamanho do imóvel 79 m²
# 3           R$ 3.490/mêsCond. R$ 1.017 • IPTU R$ 283  Tamanho do imóvel 90 m²
# 4           R$ 2.700/mêsCond. R$ 1.059 • IPTU R$ 450  Tamanho do imóvel 65 m²
#
#    Quantidade de quartos 2  Quantidade de banheiros 1  \
# 0  Quantidade de quartos 2  Quantidade de banheiros 1
# 1  Quantidade de quartos 2  Quantidade de banheiros 2
# 2  Quantidade de quartos 2  Quantidade de banheiros 2
# 3  Quantidade de quartos 3  Quantidade de banheiros 3
# 4  Quantidade de quartos 2  Quantidade de banheiros 2
#
#    Quantidade de vagas de garagem 1  \
# 0  Quantidade de vagas de garagem 1
# 1  Quantidade de vagas de garagem 1
# 2  Quantidade de vagas de garagem 1
# 3                               NaN
# 4  Quantidade de vagas de garagem 2
#
#   https://www.zapimoveis.com.br/imovel/venda-apartamento-2-quartos-com-interfone-vila-da-penha-zona-norte-rio-de-janeiro-rj-85m2-id-2775171747/?source=ranking%2Crp
# 0  https://www.zapimoveis.com.br/imovel/aluguel-a...
# 1  https://www.zapimoveis.com.br/imovel/aluguel-a...
# 2  https://www.zapimoveis.com.br/imovel/aluguel-a...
# 3  https://www.zapimoveis.com.br/imovel/aluguel-a...
# 4  https://www.zapimoveis.com.br/imovel/aluguel-a...
